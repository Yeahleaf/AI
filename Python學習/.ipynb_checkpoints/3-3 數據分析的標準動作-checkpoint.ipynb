# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
np.sin(30)
# Out:
# -0.9880316240928618

# %%
np.pi
# Out:
# 3.141592653589793

# %%
plt.plot([3, -1, 8, 0, 5, -2])

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
