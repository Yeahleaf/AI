# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
y = np.random.rand(50)

# %%
y
# Out:
# array([0.68134796, 0.56528702, 0.10596788, 0.81676199, 0.68051636,
#        0.75917787, 0.60326179, 0.2617543 , 0.29354459, 0.83012347,
#        0.82624296, 0.0463843 , 0.64770727, 0.62198441, 0.35843567,
#        0.43658466, 0.38500843, 0.76581657, 0.31187807, 0.28424735,
#        0.03983133, 0.94175779, 0.58188106, 0.31351403, 0.45363674,
#        0.59871554, 0.9497246 , 0.09669397, 0.6742122 , 0.92451488,
#        0.94419757, 0.07836224, 0.87085023, 0.07939743, 0.05776146,
#        0.34772007, 0.15474825, 0.45794778, 0.36161365, 0.94671687,
#        0.33272686, 0.54447984, 0.45833131, 0.60093829, 0.13314853,
#        0.54380448, 0.65868518, 0.30772548, 0.40548126, 0.22238768])

# %%
plt.plot(y)

# %%
np.cos(1)
# Out:
# 0.5403023058681398

# %%
np.cos(10)
# Out:
# -0.8390715290764524

# %%
np.cos(0)
# Out:
# 1.0

# %%
a = np.linspace(0, 10, 100)

# %%
a
# Out:
# array([ 0.        ,  0.1010101 ,  0.2020202 ,  0.3030303 ,  0.4040404 ,
#         0.50505051,  0.60606061,  0.70707071,  0.80808081,  0.90909091,
#         1.01010101,  1.11111111,  1.21212121,  1.31313131,  1.41414141,
#         1.51515152,  1.61616162,  1.71717172,  1.81818182,  1.91919192,
#         2.02020202,  2.12121212,  2.22222222,  2.32323232,  2.42424242,
#         2.52525253,  2.62626263,  2.72727273,  2.82828283,  2.92929293,
#         3.03030303,  3.13131313,  3.23232323,  3.33333333,  3.43434343,
#         3.53535354,  3.63636364,  3.73737374,  3.83838384,  3.93939394,
#         4.04040404,  4.14141414,  4.24242424,  4.34343434,  4.44444444,
#         4.54545455,  4.64646465,  4.74747475,  4.84848485,  4.94949495,
#         5.05050505,  5.15151515,  5.25252525,  5.35353535,  5.45454545,
#         5.55555556,  5.65656566,  5.75757576,  5.85858586,  5.95959596,
#         6.06060606,  6.16161616,  6.26262626,  6.36363636,  6.46464646,
# ...

# %%
plt.plot(a)

# %%
plt.plot(a, np.sin(a))

# %%
plt.plot(a, np.sin(a)+ a)
plt.plot(a, np.cos(a))
